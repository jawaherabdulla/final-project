# %%
#File project Jawaher Alrabiah - 
# data processing,
# Importing required libraries
import pandas as pd 
import numpy as np
#import libraries for visualisation
import seaborn as sns 
import matplotlib.pyplot as plt 
sns.set(color_codes=True)
# Read Data File open file with open() and when finish must close the file with close()
f =open("Copy of CrystalPools.csv","r")
# print file name 
print(f.name)
f.close()

# using with means to open file and allow us to work with file in this block,no need to close() file 
with open('Copy of CrystalPools.csv', 'r') as f:
    f_cont = f.readline()
    print(f_cont, end='')
    
    f_cont = f.read(100)
    print(f_cont, end='')
    
    size_to_read = 10 
    f_cont = f.read(size_to_read)
    print(f.tell())
# Out:
# Copy of CrystalPools.csv
# Month,Transaction Number,Product Code,Product Description,Store Cost,Sale Price,Profit,Commision 10%,Sales Person,Sale Location
# Jan,1,001,9822,Pool Cover,58.3,98.4,,,Chalie Barns,NM
# Jan,1,002,2877,Net,11.4,16.3,,,Juan Hernandez,238

# %%
#Loading the data into the data frame
d = pd.read_csv("Copy of CrystalPools.csv")
# To display the top 5 rows of data file
d.head(5)
# Out:
#      Month  Transaction Number  Product Code Product Description  Store Cost  \
# Jan      1                   1          9822          Pool Cover        58.3
# Jan      1                   2          2877                 Net        11.4
# Jan      1                   3          2499           8 ft Hose         6.2
# Jan      1                   4          8722          Water Pump       344.0
# Jan      1                   5          1109   Chlorine Test Kit         3.0
#
#      Sale Price  Profit  Commision 10%    Sales Person Sale Location
# Jan        98.4     NaN            NaN    Chalie Barns            NM
# Jan        16.3     NaN            NaN  Juan Hernandez            CA
# Jan         9.2     NaN            NaN      Doug Smith            AZ
# Jan       502.0     NaN            NaN    Chalie Barns            AZ
# Jan         8.0     NaN            NaN      Doug Smith            AZ

# %%
# To display the botton 5 rows
d.tail(5)
# Out:
#      Month  Transaction Number  Product Code Product Description  Store Cost  \
# Dec      1                 167          2242             AutoVac        60.0
# Dec      1                 168          9822          Pool Cover        58.3
# Dec      1                 169          8722          Water Pump       344.0
# Dec      1                 170          4421             Skimmer        45.0
# Dec      1                 171          4421             Skimmer        45.0
#
#      Sale Price  Profit  Commision 10%    Sales Person Sale Location
# Dec       124.0     NaN            NaN      Doug Smith            NM
# Dec        98.4     NaN            NaN      Doug Smith            CA
# Dec       502.0     NaN            NaN      Doug Smith            UT
# Dec        87.0     NaN            NaN    Chalie Barns            CA
# Dec        87.0     NaN            NaN  Juan Hernandez            NV

# %%
#checking types of data 
d.dtypes
# Out:
# Month                    int64
# Transaction Number       int64
# Product Code             int64
# Product Description     object
# Store Cost             float64
# Sale Price             float64
# Profit                 float64
# Commision 10%          float64
# Sales Person            object
# Sale Location           object
# dtype: object

# %%
# Dropping irrelevant columns
#d = d.drop(['Transaction Number', 'Profit', 'Commision 10%'], axis=1)
d = d.drop(['Transaction Number','Profit','Commision 10%'], axis=1)
d.head(5)
# Out:
#      Month  Product Code Product Description  Store Cost  Sale Price  \
# Jan      1          9822          Pool Cover        58.3        98.4
# Jan      1          2877                 Net        11.4        16.3
# Jan      1          2499           8 ft Hose         6.2         9.2
# Jan      1          8722          Water Pump       344.0       502.0
# Jan      1          1109   Chlorine Test Kit         3.0         8.0
#
#        Sales Person Sale Location
# Jan    Chalie Barns            NM
# Jan  Juan Hernandez            CA
# Jan      Doug Smith            AZ
# Jan    Chalie Barns            AZ
# Jan      Doug Smith            AZ

# %%
d.head()

# %%
# shape in python is the  number of elements in each dimension
# Total number of rows and columns
d.shape
# Out:
# (171, 10)

# %%
#  Renaming the columns 
# Rows containing duplicate data
duplicate_rows_d = d[d.duplicated()]
print("number of duplicate rows:", duplicate_rows_d.shape)
# Out:
# number of duplicate rows: (58, 7)

# %%
# Finding the null values.
print(d.isnull().sum())
# Out:
# Month                  0
# Product Code           0
# Product Description    0
# Store Cost             0
# Sale Price             0
# Sales Person           0
# Sale Location          0
# dtype: int64

# %%
#Detecting Outliers
sns.boxplot(x=d['Sale Price'])
# Out:
# <AxesSubplot:xlabel='Sale Price'>

# %%
# Plotting a Histogram
#visualisation
import matplotlib.pyplot as plt 
# An "interface" to matplotlib.axes.Axes.hist() method
#d, bins, patches = plt.hist(x=d, bins='auto', color='#0504aa',alpha=0.7, rwidth=0.85)
#d.Product Description.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
#plt.title("Number of Product through Months")
#plt.ylabel("Month")
#plt.xlabel("Product Description");

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= d.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#               Month  Product Code  Store Cost  Sale Price
# Month           NaN           NaN         NaN         NaN
# Product Code    NaN      1.000000    0.482697    0.476986
# Store Cost      NaN      0.482697    1.000000    0.997165
# Sale Price      NaN      0.476986    0.997165    1.000000

# %%
#### Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime
# matplotlib histogram
#plt.hist(['Product Descriptiony'], color = 'blue', edgecolor = 'black',
 #        bins = int(12))

plt.grid(axis='y', alpha=0.75)
plt.xlabel('Month')
plt.ylabel('Product Descriptiony')
plt.title('My Own Histogram')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = d.max()


df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

fig, ax = plt.subplots()
bins = np.arange(1,14)
ax.hist(months, bins = bins, edgecolor="k", align='left')
ax.set_xticks(bins[:-1])
ax.set_xticklabels([datetime.date(1900,i,1).strftime('%b') for i in bins[:-1]] )

plt.show()
